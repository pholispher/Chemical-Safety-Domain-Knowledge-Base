# %%
import pandas as pd
import os

# %%
excel_path = (
    "/root/autodl-tmp/chemical_kb/"
    "data/source/标准汇总.xlsx"
)

# %%
print("=" * 60)
print("检查Excel文件")
print("=" * 60)
# Out:
# ============================================================
# 检查Excel文件
# ============================================================

# %%
if not os.path.exists(excel_path):
    raise FileNotFoundError(
        f"找不到文件: {excel_path}"
    )


print("Excel存在:")
print(excel_path)
# Out:
# Excel存在:
# /root/autodl-tmp/chemical_kb/data/source/标准汇总.xlsx

# %%
xls = pd.ExcelFile(excel_path)

print("\n发现Sheet:")
for sheet in xls.sheet_names:
    print("-", sheet)
# Out:
# 发现Sheet:
# - 标准汇总
# - 法规

# %%
for sheet in xls.sheet_names:

    print("\n" + "="*60)
    print("Sheet:", sheet)
    print("="*60)

    df = pd.read_excel(
        excel_path,
        sheet_name=sheet
    )


    print("\n行数:")
    print(len(df))


    print("\n字段:")
    for col in df.columns:
        print("-", col)


    print("\n前3行:")
    print(df.head(3).to_string())
# Out:
# ============================================================
# Sheet: 标准汇总
# ============================================================
#
# 行数:
# 615
#
# 字段:
# - 序号
# - 文件编号
# - 文件名称
# - 实施日期
# - 状态
# - 发布日期
# - 标准编号
# - 英文标题
# - 替代情况
# - 主题分类
# - 中国标准分类号
# - 国际标准分类号
# - 发布部门
# - 归口单位
# - 起草单位
# - 起草人
# - 数据来源
#
# 前3行:
#     序号              文件编号                         文件名称        实施日期  状态        发布日期              标准编号                                                                                                                                                                     英文标题 替代情况                         主题分类                                      中国标准分类号                        国际标准分类号                                  发布部门                  归口单位                                                                                                                                起草单位                                                                                                                起草人  数据来源
# 0  1.0  DB37/T 5347-2026             城镇燃气老化管道更新改造技术标准  2026-05-01  现行  2026-01-29  DB37/T 5347-2026                                                                                                             echnical standard for renovation of city gas aging pipelines  NaN    /设备设施安全  ;  /危险化学品管理/城镇燃气               /【J】机械/【J10-29】通用零部件/【J15】管路附件  /【23】流体系统和通用件/【23.040】管道部件和管道  /山东省/山东省市场监督管理局  ;  /山东省/山东省住房和城乡建设厅      /山东省/山东省住房和城乡建设厅  山东城市建设职业学院、济南市市政工程设计研究院（集团）有限责任公司、山东省燃气热力协会、山东建筑大学、潍坊市市政公用事业服务中心、山东省城乡规划设计研究院有限公司、山东港华燃气集团有限公司、山东泰安泰山港华燃气有限公司、淄博市能源集团有限责任公司、沂水县审计局  刘庆堂、唐保金、张培新、宋克农、曹永先、郭京强、张增刚、李磊、李红玉、曹连伟、李超、杨敏华、曹东辉、张伟、徐洁、张成宝、彭晓、杜彦、胡莉娟、董先聚、郭军、刘伟、朱向凤、王雪林、苏红乡、王明、王汝建、张丽娜、陈晓明、史良、焦盈盈  地方标准
# 1  2.0  DB43/T 3447-2025             烟花爆竹生产企业对标改造技术指南  2026-03-15  现行  2025-12-15  DB43/T 3447-2025                                                                  Technical guidelines for benchmarking and upgrading of fireworksand firecrackers production enterprises  NaN                /危险化学品管理/烟花爆竹  /【C】医药、卫生、劳动保护/【C65-74】劳动安全技术/【C68】生产设备安全技术     /【13】环保、保健与安全/【13.110】机械安全                         /湖南省/湖南省应急管理厅         /湖南省/湖南省应急管理厅                                                                                                                           湖南省安全技术中心            章民、姜洲、欧阳锋、蔡亚玲、石俊、柳刚、张春华、刘捷婕、李晨晖、龙敏、杨华、刘毅、孙道武、张利、谢冬湘、谭建平、王兵、张光辉、吴鹏、郑恒、李国晖、刘雪峰、童波、李胡庆、李怡霞、黄蔚官、何昌端、王利彦、刘冬冬  地方标准
# 2  3.0  DB37/T 4995-2025  可燃液体、液化烃及液化毒性气体汽车装卸设施安全管理规范  2026-01-29  现行  2025-12-29  DB37/T 4995-2025  Specification for safety management of vehicle loading and unloading facilities for flammable and combustible liquids, liquefied hydrocarbons and liquefied toxic gases  NaN  /危险化学品管理/安全管理要求  ;  /交通运输安全          /【G】化工/【G00-09】化工综合/【G09】卫生、安全、劳动保护    /【13】环保、保健与安全/【13.300】危险品防护                       /山东省/山东省市场监督管理局  /山东省/山东省应急管理标准化技术委员会                                                    山东省应急管理厅、青岛科技大学、临沂市应急救援指挥服务中心、山东省安全技术服务中心、山东京博石油化工有限公司、寿光市应急管理局、临沂市河东区应急救援指挥服务中心                                                                                       刘迁、朱建林、孟圆圆、张衍禄、王东波、田达、陈晓、朱文秀  地方标准
#
# ============================================================
# Sheet: 法规
# ============================================================
#
# 行数:
# 240
#
# 字段:
# - 序号
# - 标题
# - 文件编号
# - 状态
# - 状态代码
# - 发布日期
# - 实施日期
# - 发布机构
# - 适用范围
# - 法规层级
# - 法规层级(提示)
# - 主分类
# - 地区
# - 点击量
# - 英文标题
# - 替代文件
# - 被替代文件
# - 章节数
# - 收藏数
# - 下载权限
# - 记录ID
# - 附件ID
# - 详情URL
# - 数据来源
#
# 前3行:
#    序号                                        标题         文件编号  状态  状态代码        发布日期        实施日期           发布机构                                                                       适用范围    法规层级 法规层级(提示)                           主分类    地区    点击量  英文标题                      替代文件 被替代文件  章节数  收藏数    下载权限                  记录ID              附件ID                                                                                                                                                                                 详情URL 数据来源
# 0   1  湖北省应急管理厅办公室印发《湖北省危险化学品建设项目安全审查要点》(试行)的通知  鄂应急〔2026〕9号  现行     2  2026-05-28  2026-05-28       湖北省应急管理厅                                                                        NaN  地方法规文件   地方法规文件  /通用安全管理/综合管理;/危险化学品管理/安全管理要求  /湖北省     22   NaN                       NaN   NaN    0    0  赠送下载权限  ZV9X49ED3DB8F163DE2F  36E2204DDFF230C1  https://law.chemicalsafety.org.cn/compliance/guild/regulation/RegulationBrowse.jsp?moduleId=2&recordId=ZV9X49ED3DB8F163DE2F&libraryId=3382332752404776&attachmentId=36E2204DDFF230C1   法规
# 1   2                  中华人民共和国药品管理法实施条例(2026修订)      国令第828号  现行     2  2026-01-16  2026-05-15            国务院                                                                        NaN    行政法规     行政法规               /危险化学品管理/安全管理要求   NaN    282   NaN  中华人民共和国药品管理法实施条例(2024修订)   NaN   98    0  赠送下载权限  ZV9X3B26E8E154C7FBB1  30733CA9D77A9D91  https://law.chemicalsafety.org.cn/compliance/guild/regulation/RegulationBrowse.jsp?moduleId=2&recordId=ZV9X3B26E8E154C7FBB1&libraryId=3382332752404776&attachmentId=30733CA9D77A9D91   法规
# 2   3                           中华人民共和国危险化学品安全法       主席令64号  现行     2  2025-12-27  2026-05-01  全国人民代表大会常务委员会  危险化学品生产、储存、使用、经营和运输的安全管理，适用本法。<br>废弃危险化学品的处置，依照有关生态环境保护的法律、行政法规和国家有关规定执行。      法律       法律               /危险化学品管理/安全管理要求   NaN  12244   NaN                       NaN   NaN  138    0  赠送下载权限  ZV9X09ADA20299EF5050  056167FD0950976C  https://law.chemicalsafety.org.cn/compliance/guild/regulation/RegulationBrowse.jsp?moduleId=2&recordId=ZV9X09ADA20299EF5050&libraryId=3382332752404776&attachmentId=056167FD0950976C   法规

# %%
pd1=pd.read_csv("/root/autodl-tmp/chemical_kb/data/parsed/document_master.csv")

# %%
pd1.head()
# Out:
#                  doc_id  doc_type              code  \
# 0  STD_DB37_T_5347_2026  standard  DB37/T 5347-2026
# 1  STD_DB43_T_3447_2025  standard  DB43/T 3447-2025
# 2  STD_DB37_T_4995_2025  standard  DB37/T 4995-2025
# 3  STD_DB11_T_1578_2025  standard  DB11/T 1578-2025
# 4   STD_DB46_T_672_2025  standard   DB46/T 672-2025
#
#                          title  status publish_date effective_date  \
# 0             城镇燃气老化管道更新改造技术标准  ACTIVE   2026-01-29     2026-05-01
# 1             烟花爆竹生产企业对标改造技术指南  ACTIVE   2025-12-15     2026-03-15
# 2  可燃液体、液化烃及液化毒性气体汽车装卸设施安全管理规范  ACTIVE   2025-12-29     2026-01-29
# 3              医疗机构危险化学品安全管理要求  ACTIVE   2025-04-01     2025-07-01
# 4               醇基液体燃料安全检查工作规范  ACTIVE   2025-02-28     2025-04-01
#
#                                  issuer          organization  \
# 0  /山东省/山东省市场监督管理局  ;  /山东省/山东省住房和城乡建设厅      /山东省/山东省住房和城乡建设厅
# 1                         /湖南省/湖南省应急管理厅         /湖南省/湖南省应急管理厅
# 2                       /山东省/山东省市场监督管理局  /山东省/山东省应急管理标准化技术委员会
# 3                        /北京/北京市市场监督管理局          /北京/北京市应急管理局
# 4                       /海南省/海南省市场监督管理局         /海南省/海南省应急管理厅
#
#                          topic region level            replacement record_id  \
# 0    /设备设施安全  ;  /危险化学品管理/城镇燃气    NaN    标准                    NaN       NaN
# 1                /危险化学品管理/烟花爆竹    NaN    标准                    NaN       NaN
# 2  /危险化学品管理/安全管理要求  ;  /交通运输安全    NaN    标准                    NaN       NaN
# 3              /危险化学品管理/安全管理要求    NaN    标准  替代  DB11/T 1578-2018;       NaN
# 4              /危险化学品管理/安全管理要求    NaN    标准                    NaN       NaN
#
#   attachment_id source  pdf_path
# 0           NaN   地方标准       NaN
# 1           NaN   地方标准       NaN
# 2           NaN   地方标准       NaN
# 3           NaN   地方标准       NaN
# 4           NaN   地方标准       NaN
